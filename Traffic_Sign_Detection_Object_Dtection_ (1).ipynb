# %%
import os

if 'COLAB_GPU' in os.environ:
  print("GPU is enabled!")
else:
  print("GPU is not enabled!")
# Out:
# GPU is enabled!

# %% [markdown]
# Install YOLOv11

# %%
# !pip install torch>=2.1.0 torchvision>=0.16.0 ultralytics>=8.3.0

# %%
import torch, ultralytics
ultralytics.checks()
print("Torch version:", torch.__version__)
print("Ultralytics version:", ultralytics.__version__)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.3/112.6 GB disk)
# Torch version: 2.8.0+cu126
# Ultralytics version: 8.3.226

# %% [markdown]
# Importing dataset

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir TrafficSignDetection

# %%
# !ls
# Out:
# '=0.16.0'  '=2.1.0'  '=8.3.0'   TrafficSignDetection

# %%
path ='/content/TrafficSignDetection'
print(path)
# Out:
# /content/TrafficSignDetection

# %%
# %pwd
# Out:
# '/content'

# %%
os.chdir('/content/TrafficSignDetection')
# %pwd
# Out:
# '/content/TrafficSignDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="mkOEmOZeQ47hcpgC2bnk")
project = rf.workspace("traffic-sign-detection-80yhm").project("traffic-sign-detection-fvaoc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-Sign-Detection-1 in yolov11:: 100%|██████████| 21972/21972 [00:03<00:00, 6088.86it/s]

# %% [markdown]
# Train YOLO over Custom dataset

# %%
import os
os.chdir("/content/TrafficSignDetection/Traffic-Sign-Detection-1/Traffic-Sign-Detection-1")

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=data.yaml epochs=10, imgsz=640, batch = 16
# Out:
# WARNING ⚠️ argument 'epochs=10,' does not require trailing comma ',', updating to 'epochs=10'.
# WARNING ⚠️ argument 'imgsz=640,' does not require trailing comma ',', updating to 'imgsz=640'.
# ...
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
